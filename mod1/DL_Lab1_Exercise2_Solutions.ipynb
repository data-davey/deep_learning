# %% [markdown]
# # **Lab: PyTorch**

# %% [markdown]
# ## Exercise 2: Tensors Operations
#
# In this exercise, we will learn how to perform mathematical operations on tensors using PyTorch
#
# The steps are:
# 1.   Mathematical Operations
# 2.   Reimplementing Matrix Multiplication
# 3.   Other Operations

# %% [markdown]
# ## 1. Mathematical Operations

# %% [markdown]
# **[1.1]** Import PyTorch and numpy packages

# %%
# Placeholder for student's code

# %%
# Solution
import torch
import numpy as np

# %% [markdown]
# **[1.2]** Create a tensor called `a` that will contain the following values: [1, 2], [3, 4]

# %%
# Placeholder for student's code

# %%
# Solution
a = torch.tensor([[1, 2], [3, 4]])
a
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %% [markdown]
# **[1.3]** Create a tensor called `b` of shape (2,2) that will contain only the value 1

# %%
# Placeholder for student's code

# %%
# Solution
b = torch.ones([2,2])
b
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %% [markdown]
# **[1.4]** Perform element-wise addition between `a` and `b`

# %%
# Placeholder for student's code

# %%
# Solution
torch.add(a,b)
# Out:
# tensor([[2., 3.],
#         [4., 5.]])

# %% [markdown]
# **[1.5]** Convert data type of `a` to float

# %%
# Placeholder for student's code

# %%
# Solution
a = torch.tensor([[1., 2.], [3., 4.]])
a
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %% [markdown]
# **[1.6]** Perform element-wise addition between `a` and `b`

# %%
# Placeholder for student's code

# %%
# Solution
torch.add(a, b)
# Out:
# tensor([[2., 3.],
#         [4., 5.]])

# %% [markdown]
# **[1.7]** Perform element-wise multiplication between `a` and `b`

# %%
# Placeholder for student's code

# %%
# Solution
torch.mul(a, b)
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %% [markdown]
# **[1.8]** Perform matrix multiplication between `a` and `b`

# %%
# Placeholder for student's code

# %%
# Solution
torch.matmul(a, b)
# Out:
# tensor([[3., 3.],
#         [7., 7.]])

# %% [markdown]
# ## 2. Reimplementing Matrix Multiplication

# %% [markdown]
# **[2.1]** Create a tensor called `c` that will contain the following values: [1, 2, 3], [4, 5, 6]

# %%
# Placeholder for student's code

# %%
# Solution
c = torch.tensor([[1., 2., 3.], [4., 5., 6.]])
c
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]])

# %% [markdown]
# **[2.2]** Create a tensor called `d` that will contain the following values: [7, 8], [9, 10], [11, 12]

# %%
# Placeholder for student's code

# %%
# Solution
d = torch.tensor([[7., 8.], [9., 10.], [11., 12.]])
d
# Out:
# tensor([[ 7.,  8.],
#         [ 9., 10.],
#         [11., 12.]])

# %% [markdown]
# **[2.3]** Perform matrix multiplication between `c` and `d`

# %%
# Placeholder for student's code

# %%
# Solution
c @ d
#torch.matmul(c,d)
# Out:
# tensor([[ 58.,  64.],
#         [139., 154.]])

# %% [markdown]
# ![Screenshot 2025-02-17 at 22.18.43.png](data:image/png;base64,...)

# %% [markdown]
# **[2.4]** Perform element-wise multiplication between the first dimension of `c` and the first element of each dimension of`d`

# %%
# Placeholder for student's code

# %%
# Solution
c[0] * d[:,0]
# Out:
# tensor([ 7., 18., 33.])

# %% [markdown]
# ![Screenshot 2025-02-17 at 22.21.54.png](data:image/png;base64,...)

# %% [markdown]
# **[2.5]** Perform element-wise multiplication between the first dimension of `c` and the first element of each dimension of`d` and then sum them
#
# (1, 2, 3) • (7, 9, 11) = 1×7 + 2×9 + 3×11 = 58

# %%
# Placeholder for student's code

# %%
# Solution
torch.sum(c[0] * d[:,0])
# Out:
# tensor(58.)

# %% [markdown]
# **[2.6]** Perform element-wise multiplication between the first dimension of `c` and the second element of each dimension of `d` and then sum them
#
# (1, 2, 3) • (8, 10, 12) = 1×8 + 2×10 + 3×12 = 64

# %%
# Placeholder for student's code

# %%
# Solution
torch.sum(c[0] * d[:,1])
# Out:
# tensor(64.)

# %% [markdown]
# **[2.7]** Perform element-wise multiplication between the second dimension of `c` and the first element of each dimension of `d` and then sum them
#
# (4, 5, 6) • (7, 9, 11) = 4×7 + 5×9 + 6×11
#     = 139

# %%
# Placeholder for student's code

# %%
# Solution
torch.sum(c[1] * d[:,0])
# Out:
# tensor(139.)

# %% [markdown]
# **[2.8]** Perform element-wise multiplication between the second dimension of `c` and the second element of each dimension of `d` and then sum them
#
# (4, 5, 6) • (8, 10, 12) = 4×8 + 5×10 + 6×12 = 154

# %%
# Placeholder for student's code

# %%
# Solution
torch.sum(c[1] * d[:,1])
# Out:
# tensor(154.)

# %% [markdown]
# ## 3. Other Operations

# %% [markdown]
# **[3.1]** Create a tensor called `e` that will contain the following values: [4, -5, 10, -1, 0]

# %%
# Placeholder for student's code

# %%
# Solution
e = torch.tensor([4.0, -5.0, 10.0, -1.0, 0.])
e
# Out:
# tensor([ 4., -5., 10., -1.,  0.])

# %% [markdown]
# **[3.2]** Find the maximum value of `e`

# %%
# Placeholder for student's code

# %%
# Solution
torch.max(e)
# Out:
# tensor(10.)

# %% [markdown]
# **[3.3]** Find the index of the maximum value of `e`

# %%
# Placeholder for student's code

# %%
# Solution
torch.argmax(e)
# Out:
# tensor(2)

# %% [markdown]
# **[3.4]** Apply sigmoid on `e`

# %%
# Placeholder for student's code

# %%
# Solution
torch.sigmoid(e)
# Out:
# tensor([0.9820, 0.0067, 1.0000, 0.2689, 0.5000])

# %% [markdown]
# **[3.5]** Apply relu on `e`

# %%
# Placeholder for student's code

# %%
# Solution
relu = torch.nn.ReLU()
relu(e)
# Out:
# tensor([ 4.,  0., 10.,  0.,  0.])

# %% [markdown]
# **[3.6]** Apply softmax on `e`

# %%
# Placeholder for student's code

# %%
# Solution
m = torch.nn.Softmax(dim=0)
m(e)
# Out:
# tensor([2.4725e-03, 3.0513e-07, 9.9747e-01, 1.6659e-05, 4.5285e-05])
